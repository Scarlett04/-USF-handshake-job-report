# %%
import pandas as pd
import numpy as np
import math

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data_final.csv")
df_modify = df.copy()

# %%
df_modify.head(10)
# Out:
#                                            Job Title  \
# 0  Cristo Rey Full-Time Residential Fellowship Pr...
# 1                                    Teaching Fellow
# 2  U.S. Department of State Consular Fellows Program
# 3  Foreign Affairs Information Technology Fellowship
# 4                       Account Executive - Athletes
# 5            Full Tuition Medical School Scholarship
# 6            Holy Family Service Corps Nazareth Year
# 7                Psychological Operations Specialist
# 8    2023 Spring Supply Chain Co-op - July- December
# 9  Social Media Marketing Experiential Learning O...
#
#                                      Job Info  \
# 0                      Full-Time ∙ Fellowship
# 1                      Full-Time ∙ Fellowship
# 2                      Full-Time ∙ Fellowship
# 3                      Full-Time ∙ Fellowship
# 4           Full-Time ∙ Experiential Learning
# 5           Part-Time ∙ Experiential Learning
# 6                       Full-Time ∙ Volunteer
# ...

# %%
df['Job Description'].head(1).values.tolist()
# Out:
# ['The Cristo Rey New York Residential Fellowship Program seeks dynamic, thoughtful young men and women of promise who are committed to sharing their many gifts and talents with our students.\nThis full-time, residential fellowship program requires a two-year commitment and fellows serve the community in various ways such as teaching, assistant teaching, fundraising, moderating extra-curricular activities, coaching, and training and chaperoning students in support of our Corporate Work Study Program.\nThe alumni/ae of our program have gone on to meaningful careers in law, social work, business, nursing, education, public policy, and more.\n The program runs for just over 22 months, from mid-August through late June. Fellows will also attend a week-long training and orientation in July of year one.\n Benefits of the Program\nMentoring by experienced teachers\nOpportunities for spiritual and personal growth\nCommunity living in housing provided by Cristo Rey New York\nA stipend for pers
# ...
